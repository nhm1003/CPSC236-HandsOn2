# %% [markdown]
# # Selections and Loops

# %% [markdown]
# ## 3.1 Letter Grade Converter
# Create a program that converts number grades to letter grades.
#
# ### Console:
# ```powershell
# Letter Grade Converter
#
# Enter numerical grade: 90
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 88
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 80
# Letter grade: B
#
# Continue? (y/n): y
#
# Enter numerical grade: 67
# Letter grade: C
#
# Continue? (y/n): y
#
# Enter numerical grade: 59
# Letter grade: F
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Assume that the user will enter valid integers for the grades.
# - The program should continue only if the user enters “y” or “Y” to continue.
# - The grading criteria is as follows:
#
# | Letter |	Range |
# |---|-------|
# | A |	88-100 |
# | B |	80-87 |
# | C |	67-79 |
# | D |	60-66 |
# | F |	<60 |

# %%
print("Letter Grade Converter")
print()
yayNay = True
while yayNay == True:
    nGrade = int(input("Enter numerical grade: "))
    if nGrade >= 88:
        print("Letter grade: A")
    elif nGrade >= 80:
        print("Letter grade: B")
    elif nGrade >= 67:
        print("Letter grade: C")
    elif nGrade >= 60:
        print("Letter grade: D")
    else:
        print("Letter grade: F")
    print(" ")
    cont = input("Continue? (y/n):")
    if cont == "Y" or cont == "y":
        yayNay = True
    else:
        yayNay = False
    print("")
print("Bye!")
# Out:
# Letter Grade Converter
# Enter numerical grade:  90
# Letter grade: A
# Continue? (y/n): y
# Enter numerical grade:  80
# Letter grade: B
# Continue? (y/n): y
# Enter numerical grade:  70
# Letter grade: C
# Continue? (y/n): y
# Enter numerical grade:  60
# Letter grade: D
# Continue? (y/n): y
# Enter numerical grade:  50
# Letter grade: F
# Continue? (y/n): n
# Bye!

# %% [markdown]
# ## 3.2 - Tip Calculator
# Create a program that calculates three options for an appropriate tip to leave after a meal at a restaurant.
#
# ### Console
# ```powershell
# Tip Calculator
#
# Cost of meal: 52.31
#
# 15%
# Tip amount:	7.85
# Total amount: 60.16
#
# 20%
# Tip amount:	10.46
# Total amount: 62.77
#
# 25%
# Tip amount:	13.08
# Total amount: 65.39
# ```
#
# ### Specifications:
# - The program should calculate and display the cost of tipping at 15%, 20%, or 25%.
# - Assume the user will enter valid data.
# - The program should round results to a maximum of two decimal places.

# %%
print("Tip Calculator")
print("")
price = float(input("Cost of meal: "))
print("")
for i in range(15,26,5):
    print(str(i) + "%")
    tipAmount = round(((price*i)/100), 2)
    print("Tip Amount: \t", tipAmount)
    totalAmount = round((price + tipAmount),2)
    print("Total Amount:", totalAmount)
    print()
# Out:
# Tip Calculator
# Cost of meal:  15.57
# 15%
# Tip Amount: 	 2.34
# Total Amount: 17.91
#
# 20%
# Tip Amount: 	 3.11
# Total Amount: 18.68
#
# 25%
# Tip Amount: 	 3.89
# Total Amount: 19.46

# %% [markdown]
# ## 3.3 - Change Calculator
# Create a program that calculates the coins needed to make change for the specified number of cents.
#
# ### Console
# ```powershell
# Change Calculator
#
# Enter number of cents (0-99): 99
#
# Quarters: 3
# Dimes:	2
# Nickels: 0
# Pennies: 4
#
# Continue? (y/n): y
#
# Enter number of cents (0-99): 55
#
# Quarters: 2
# Dimes:	0
# Nickels: 1
# Pennies: 0
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications
# - The program should display the minimum number of quarters, dimes, nickels, and pennies that one needs to make up the specified number of cents.
# - Assume that the user will enter a valid integer for the number of cents.
# - The program should continue only if the user enters “y” or “Y” to continue.

# %%
print("Change Calculator")
print()
cont = True
quarters = 0
dimes = 0
nickles = 0
pennies = 0
ask = ""
while cont == True: 
    cents = int(input("Enter number of cents (0-99): "))
    print()
    quarters = cents // 25
    cents -= (quarters * 25)
    print("Quarters: ", quarters)
    dimes = cents // 10
    cents -= (dimes * 10)
    print("Dimes: ", dimes)
    nickles = cents // 5
    cents -= (nickles * 5)
    print("Nickles: ", nickles)
    pennies = cents // 1
    cents -+ (pennies * 1)
    print("Pennies: ", pennies)
    print()
    ask = input("Continue? (y/n): ")
    if ask.lower() == "y":
        cont = True
    else:
        cont = False
    print()
print()
print("Bye!")
# Out:
# Change Calculator
# Enter number of cents (0-99):  99
# Quarters:  3
# Dimes:  2
# Nickles:  0
# Pennies:  4
# Continue? (y/n):  y
# Enter number of cents (0-99):  55
# Quarters:  2
# Dimes:  0
# Nickles:  1
# Pennies:  0
# Continue? (y/n):  y
# Enter number of cents (0-99):  41
# Quarters:  1
# Dimes:  1
# Nickles:  1
# Pennies:  1
# Continue? (y/n):  y
# Enter number of cents (0-99):  0
# Quarters:  0
# Dimes:  0
# Nickles:  0
# Pennies:  0
# Continue? (y/n):  y
# Enter number of cents (0-99):  1
# Quarters:  0
# Dimes:  0
# Nickles:  0
# Pennies:  1
# Continue? (y/n):  n
# Bye!

# %% [markdown]
# ## 3.4 - Table of Powers
# Create a program that displays a table of squares and cubes for the specified range of numbers.
#
# ### Console
# ```powershell
# Table of Powers
#
# Start number: 90
# Stop number: 100
#
# Number	Squared	Cubed
# ======	=======	=====
# 90      8100	729000
# 91      8281	753571
# 92      8464	778688
# 93      8649	804357
# 94      8836	830584
# 95      9025	857375
# 96      9216	884736
# 97      9409	912673
# 98      9604	941192
# 99      9801	970299
# 100     10000	1000000
# ```
#
# ### Specifications
# - The formulas for calculating squares and cubes are:
#
#     `square = x ** 2`
#
#     `cube = x ** 3`
#
# - Use tabs to align the columns.
# - Assume that the user will enter valid integers.
# - Make sure the user enters a start integer that’s less than the stop integer. If the user enters a start integer that’s greater than the stop integer, display an error message and give the user a chance to enter the integers again.

# %%
print("Table of Powers")    
startNum = int(input("Start Number: "))
stopNum = int(input("Stop Number: "))
while not startNum < stopNum:
    print("Error: Start Number must be less than Stop Number.")
    startNum = int(input("Start Number: "))
    stopNum = int(input("Stop Number: "))
print("Number\tSquared\tCubed")
print("======\t=======\t=====")
for i in range(startNum, stopNum + 1):
    sqNum = i ** 2
    cubeNum = i ** 3
    #parsed to string and concatinated so that formatting matched that of  
    print(str(i) + "\t" + str(sqNum) + "\t" + str(cubeNum))
# Out:
# Table of Powers
# Start Number:  12
# Stop Number:  8
# Error: Start Number must be less than Stop Number.
# Start Number:  12
# Stop Number:  24
# Number	Squared	Cubed
# ======	=======	=====
# 12	144	1728
# 13	169	2197
# 14	196	2744
# 15	225	3375
# 16	256	4096
# 17	289	4913
# 18	324	5832
# 19	361	6859
# 20	400	8000
# 21	441	9261
# 22	484	10648
# 23	529	12167
# 24	576	13824
